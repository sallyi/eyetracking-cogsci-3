# %%
import pandas as pd
import re

# %% [markdown]
# ## Load Sequence Data
# To Determine Primers

# %%
sequences_df = pd.read_csv('sequences_all.tsv', delimiter='\t')
sequence_order_primer_type_df  = sequences_df.melt(id_vars= sequences_df.columns[0]) 
def funct_or_emo(string):
    if '-emo'in string:
        return 'emotional'
    if '-funct' in string:
        return 'functional'
    if '__' in string:
        return 'crosshair'
    return 'image'

def get_primed_image(string):
    if 'primer'in string:
        return re.search(r"-(?:emo|funct)-(.+)", string).group(1)
    return '_'.join(string.split('_')[1:])
sequence_order_primer_type_df['primer-type'] =  sequence_order_primer_type_df.value.apply(funct_or_emo)
sequence_order_primer_type_df['primed-image'] =  sequence_order_primer_type_df.value.apply(get_primed_image)
sequence_order_primer_type_df
# Out:
#      Sequence name/ Order variable                             value  \
# 0                       A        0  0_primer-funct-4_floor-cleaner-4
# 1                       B        0    0_primer-emo-4_floor-cleaner-4
# 2                       C        0     123_primer-emo-2_car-inside-3
# 3                       D        0   123_primer-funct-2_car-inside-3
# 4                       E        0  0_primer-funct-4_floor-cleaner-4
# ...                   ...      ...                               ...
# 1723                    H      143                125_2_car-inside-3
# 1724                    I      143                      20_1_kitchen
# 1725                    J      143                      20_1_kitchen
# 1726                    K      143              23_4_floor-cleaner-1
# 1727                    L      143              23_4_floor-cleaner-1
#
#      primer-type       primed-image
# 0     functional  4_floor-cleaner-4
# 1      emotional  4_floor-cleaner-4
# 2      emotional     2_car-inside-3
# 3     functional     2_car-inside-3
# 4     functional  4_floor-cleaner-4
# ...          ...                ...
# 1723       image     2_car-inside-3
# 1724       image          1_kitchen
# 1725       image          1_kitchen
# 1726       image  4_floor-cleaner-1
# 1727       image  4_floor-cleaner-1
#
# [1728 rows x 5 columns]

# %%
sequences_df.columns[0]
# Out:
# 'Sequence name/ Order'

# %%
survey_df = pd.read_csv('Experiment check list - survey responses.tsv', delimiter='\t')
survey_df.head()
# Out:
#              Timestamp Please write your Subject ID number  \
# 0  11/13/2019 20:33:49                                P001
# 1   11/15/2019 9:18:27                                P002
# 2  11/15/2019 10:00:40                                P003
# 3  11/15/2019 12:14:16                                P004
# 4  11/15/2019 12:18:23                                P005
#
#   What is your gender?  What is your age?  \
# 0               Female                 26
# 1               Female                 24
# 2               Female                 24
# 3               Female                 26
# 4               Female                 24
#
#   Are you wearing glasses or contact lenses? What is your first language?  \
# 0                                        NaN                          NaN
# 1                      I am wearing neither.                       Danish
# 2                      I am wearing neither.                       Danish
# 3                      I am wearing neither.                       Danish
# 4                      I am wearing neither.                   Lithuanian
#
#   Are you currently enrolled in a Cognitive Science course?  image 1 - face  \
# 0                                                NaN                      5
# 1                                                Yes                      5
# 2                                                 No                      5
# 3                                                 No                      5
# 4                                                Yes                      4
#
#    image 2 - face  image 3 - face  image 4 - face  image 5 - face  \
# 0               4               4               5               3
# 1               4               4               2               1
# 2               5               5               5               5
# 3               5               5               5               4
# 4               4               3               2               3
#
#    image 6 - face  image 7 - face  image 8 - face  image 9 - face  \
# 0               2               3               4               4
# 1               5               3               1               1
# 2               5               3               5               5
# 3               5               5               5               4
# 4               1               3               2               2
#
#    image 10 - face
# 0                3
# 1                4
# 2                3
# 3                5
# 4                1

# %% [markdown]
# ## Survey Data
# #### Get stats for image ratings

# %%
image_cols = [col for col in survey_df.columns if 'image' in col]
image_ratings_df = pd.DataFrame(survey_df[image_cols].mean()).rename(columns={0:'mean'})
image_ratings_df['median'] = survey_df[image_cols].median()
image_ratings_df['stdev'] = survey_df[image_cols].std()
image_ratings_df
# Out:
#                      mean  median     stdev
# image 1 - face   4.833333     5.0  0.379049
# image 2 - face   4.733333     5.0  0.520830
# image 3 - face   4.200000     4.5  0.961321
# image 4 - face   4.166667     4.5  1.053183
# image 5 - face   3.500000     3.5  1.224745
# image 6 - face   3.366667     3.0  1.425950
# image 7 - face   3.166667     3.0  1.147211
# image 8 - face   3.033333     3.0  1.245221
# image 9 - face   3.066667     3.0  1.201532
# image 10 - face  2.833333     3.0  1.341212

# %%
image_ratings_df['mean'].mean()
# Out:
# 3.6900000000000004

# %%
with open('image_ratings.tex','w') as rf:
    rf.write(image_ratings_df.to_latex(index=True))

# %%
subjects_df = pd.read_csv('Experiment check list - subjects.tsv', delimiter='\t')
subjects_df = subjects_df.join(survey_df)
subjects_df
# Out:
#    ID number       name consent form                     lights TOBII ID  \
# 0       P001  Kornelija            n  close window, full indoor     P001
# 1       P002     Clara             y  close window, full indoor     P002
# 2       P003     Tereza            y  close window, full indoor     P003
# 3       P004        NaN            y  close window, full indoor     P004
# 4       P005        NaN            y  close window, full indoor     P005
# 5       P006        NaN            y  close window, full indoor     P006
# 6       P007        NaN            y  close window, full indoor     P007
# 7       P008        NaN            y  close window, full indoor     P008
# 8       P009        NaN            y  close window, full indoor     P009
# 9       P010        NaN            y  close window, full indoor     P010
# 10      P011        NaN            y  close window, full indoor     P011
# 11      P012        NaN            y  close window, full indoor     P012
# 12      P013        NaN            y  close window, full indoor     P013
# 13      P014        NaN            y  close window, full indoor     P014
# 14      P015        NaN            y  close window, full indoor     P015
# 15      P016        NaN            y  close window, full indoor     P016
# 16      P017        NaN            y  close window, full indoor     P017
# 17      P018        NaN            y  close window, full indoor     P018
# 18      P019        NaN            y  close window, full indoor     P019
# 19      P020        NaN            y  close window, full indoor     P020
# 20      P021        NaN            y  close window, full indoor     P021
# 21      P022        NaN            y  close window, full indoor     P022
# 22      P023        NaN            y  close window, full indoor     P023
# 23      P024        NaN            y  close window, full indoor     P024
# 24      P025        NaN            y  close window, full indoor     P025
# 25      P026        NaN            y  close window, full indoor     P026
# 26      P027        NaN            y  close window, full indoor     P027
# 27      P028        NaN            y  close window, full indoor     P028
# 28      P029        NaN            y  close window, full indoor     P029
# 29      P030        NaN            y  close window, full indoor     P030
#
#      RecordingID  Duration (seconds)  Weighted Gaze Samples (%)  \
# 0         Rec 01               457.8                         63
# 1   E_P002_rec01               492.4                         60
# 2    F_p003_rec1               411.6                         43
# 3    A_p004_rec1               407.4                         47
# 4    B_p005_rec1               367.1                          7
# 5      C_p006_01               347.8                         14
# 6    D_p007_rec1               360.1                         93
# 7    E_p008_rec1               410.4                         18
# 8     F_009_rec1               391.7                         49
# 9    A_P010_rec1               479.6                         53
# 10        B_P011               441.1                         87
# 11        C_P012               355.6                         92
# 12        D_P013               441.9                         97
# 13        E_P014               462.6                         65
# 14        F_P015               420.6                         90
# 15        A_P016               407.5                         95
# 16      B_Rec 03               353.3                         15
# 17      C_Rec 04               406.0                         93
# 18        D_P019               419.5                         89
# 19        E_P020               458.7                         78
# 20        F_P021               597.4                         89
# 21     A_22_REC1               414.3                         83
# 22   B_P023_REC1               421.4                         89
# 23    C_024_REC1               373.9                         92
# 24    D_025_REC1               335.2                         94
# 25    E_026_REC1               414.5                         58
# 26    F_026-REC1               397.3                         95
# 27    A_028-REC1               372.3                         76
# 28         B_029               353.1                         94
# 29       C_030-1               332.7                         56
#
#     Gaze Samples (%) callibration  ... image 1 - face image 2 - face  \
# 0                 64            y  ...              5              4
# 1                 62            y  ...              5              4
# 2                 43            y  ...              5              5
# 3                 50            y  ...              5              5
# 4                  7            y  ...              4              4
# 5                 14            y  ...              5              4
# 6                 93            y  ...              5              5
# 7                 19            y  ...              5              5
# 8                 49            y  ...              5              5
# 9                 53            y  ...              5              5
# 10                89            y  ...              4              4
# 11                95            y  ...              5              5
# 12                98            y  ...              5              3
# 13                65            y  ...              5              5
# 14                91            y  ...              4              5
# 15                95            y  ...              4              5
# 16                15            y  ...              5              5
# 17                93            y  ...              5              5
# 18                89            y  ...              5              5
# 19                78            y  ...              5              5
# 20                92            y  ...              5              5
# 21                86            y  ...              5              5
# 22                89            y  ...              5              5
# 23                93            y  ...              5              5
# 24                97            y  ...              4              4
# 25                58            y  ...              5              5
# 26                96            y  ...              5              5
# 27                76            y  ...              5              5
# 28                94            y  ...              5              5
# 29                61          NaN  ...              5              5
#
#    image 3 - face image 4 - face image 5 - face image 6 - face  \
# 0               4              5              3              2
# 1               4              2              1              5
# 2               5              5              5              5
# 3               5              5              4              5
# 4               3              2              3              1
# 5               5              4              4              2
# 6               5              4              5              4
# 7               4              4              5              5
# 8               2              5              3              4
# 9               5              3              3              3
# 10              5              3              2              1
# 11              5              4              4              2
# 12              3              2              4              3
# 13              4              4              3              4
# 14              3              4              3              2
# 15              4              5              2              4
# 16              4              5              3              3
# 17              2              5              1              3
# 18              5              5              4              5
# 19              4              5              3              2
# 20              5              5              2              1
# 21              5              5              5              5
# 22              5              2              3              2
# 23              4              5              2              3
# 24              3              4              4              3
# 25              3              4              4              2
# 26              5              5              5              5
# 27              5              4              5              5
# 28              5              5              5              5
# 29              5              5              5              5
#
#     image 7 - face image 8 - face image 9 - face image 10 - face
# 0                3              4              4               3
# 1                3              1              1               4
# 2                3              5              5               3
# 3                5              5              4               5
# 4                3              2              2               1
# 5                2              3              3               1
# 6                3              3              3               3
# 7                3              2              4               2
# 8                4              2              2               2
# 9                4              3              4               2
# 10               1              2              4               3
# 11               3              3              2               3
# 12               2              2              2               1
# 13               5              3              3               4
# 14               2              3              2               2
# 15               2              1              3               2
# 16               3              2              2               3
# 17               3              3              1               2
# 18               3              4              2               2
# 19               4              4              4               1
# 20               1              1              4               1
# 21               5              5              5               5
# 22               4              4              3               4
# 23               2              4              2               5
# 24               3              2              3               2
# 25               2              2              2               2
# 26               5              5              5               5
# 27               3              5              4               4
# 28               5              3              2               3
# 29               4              3              5               5
#
# [30 rows x 30 columns]

# %%
def get_image_name(x):
    match = re.match(r"(.+\.png)", x)
    if match is not None:
        #print(match.group(0))
        return '_'.join(match.group(0).split('.')[0].split('_')[2:])
    return None

def get_aoi_name(x):
    return x.split("_")[-2]

# %% [markdown]
# ## First Fixation Duration

# %%
first_fixation_duration_df = pd.read_csv('summary-stats/First Fixation Duration.txt', delimiter='\t')
first_fixation_duration_df.head()
# Out:
#   Unnamed: 0 First Fixation Duration_14_5_car-front-seat.png_face_N  \
# 0       P001                                                  1
# 1       P002                                                  1
# 2       P003                                                  1
# 3       P004                                                  1
# 4       P005                                                  -
#
#   First Fixation Duration_14_5_car-front-seat.png_face_Mean  \
# 0                                               0,22
# 1                                               0,32
# 2                                               0,39
# 3                                               0,27
# 4                                                  -
#
#   First Fixation Duration_14_5_car-front-seat.png_face_Max  \
# 0                                               0,22
# 1                                               0,32
# 2                                               0,39
# 3                                               0,27
# 4                                                  -
#
#   First Fixation Duration_14_5_car-front-seat.png_face_Min  \
# 0                                               0,22
# 1                                               0,32
# 2                                               0,39
# 3                                               0,27
# 4                                                  -
#
#   First Fixation Duration_14_5_car-front-seat.png_face_Sum  \
# 0                                               0,22
# 1                                               0,32
# 2                                               0,39
# 3                                               0,27
# 4                                                  -
#
#   First Fixation Duration_14_5_car-front-seat.png_face_Median  \
# 0                                               0,22
# 1                                               0,32
# 2                                               0,39
# 3                                               0,27
# 4                                                  -
#
#   First Fixation Duration_14_5_car-front-seat.png_face_Stdev  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
#   First Fixation Duration_14_5_car-front-seat.png_Rectangle 2_N  \
# 0                                                  1
# 1                                                  1
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
#   First Fixation Duration_14_5_car-front-seat.png_Rectangle 2_Mean  ...  \
# 0                                               0,19                ...
# 1                                               0,01                ...
# 2                                                  -                ...
# 3                                                  -                ...
# 4                                                  -                ...
#
#   First Fixation Duration_57_9_furniture.png_Rectangle 3_Sum  \
# 0                                                  -
# 1                                               0,24
# 2                                               0,01
# 3                                               0,25
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Rectangle 3_Median  \
# 0                                                  -
# 1                                               0,24
# 2                                               0,01
# 3                                               0,25
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Rectangle 3_Stdev  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Not on AOI_N  \
# 0                                                  -
# 1                                                  1
# 2                                                  -
# 3                                                  1
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Not on AOI_Mean  \
# 0                                                  -
# 1                                               0,17
# 2                                                  -
# 3                                               0,15
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Not on AOI_Max  \
# 0                                                  -
# 1                                               0,17
# 2                                                  -
# 3                                               0,15
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Not on AOI_Min  \
# 0                                                  -
# 1                                               0,17
# 2                                                  -
# 3                                               0,15
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Not on AOI_Sum  \
# 0                                                  -
# 1                                               0,17
# 2                                                  -
# 3                                               0,15
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Not on AOI_Median  \
# 0                                                  -
# 1                                               0,17
# 2                                                  -
# 3                                               0,15
# 4                                                  -
#
#   First Fixation Duration_57_9_furniture.png_Not on AOI_Stdev
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
# [5 rows x 218 columns]

# %%
first_fixation_dur_df = first_fixation_duration_df.melt(
    id_vars=first_fixation_duration_df.columns[0])
first_fixation_dur_df = first_fixation_dur_df.rename(columns={"Unnamed: 0": "ID number"})
first_fixation_dur_df['metric'] = 'First Fixation Duration'
first_fixation_dur_df['image_AOI_measure'] = first_fixation_dur_df[[
    'metric', 'variable']].apply(lambda x: re.sub(x[0]+'_', '', x[1]), axis=1)

first_fixation_dur_df['image'] = first_fixation_dur_df['image_AOI_measure'].apply(get_image_name)
first_fixation_dur_df['AOI'] = first_fixation_dur_df['image_AOI_measure'].apply(lambda x: x.split("_")[-2])
first_fixation_dur_df['measurement'] = first_fixation_dur_df['image_AOI_measure'].apply(lambda x: x.split("_")[-1])
first_fixation_dur_df
# Out:
#            ID number                                           variable value  \
# 0               P001  First Fixation Duration_14_5_car-front-seat.pn...     1
# 1               P002  First Fixation Duration_14_5_car-front-seat.pn...     1
# 2               P003  First Fixation Duration_14_5_car-front-seat.pn...     1
# 3               P004  First Fixation Duration_14_5_car-front-seat.pn...     1
# 4               P005  First Fixation Duration_14_5_car-front-seat.pn...     -
# ...              ...                                                ...   ...
# 6722            P027  First Fixation Duration_57_9_furniture.png_Not...     -
# 6723            P028  First Fixation Duration_57_9_furniture.png_Not...     -
# 6724            P029  First Fixation Duration_57_9_furniture.png_Not...     -
# 6725            P030  First Fixation Duration_57_9_furniture.png_Not...     -
# 6726  All Recordings  First Fixation Duration_57_9_furniture.png_Not...  0,11
#
#                        metric                    image_AOI_measure  \
# 0     First Fixation Duration       14_5_car-front-seat.png_face_N
# 1     First Fixation Duration       14_5_car-front-seat.png_face_N
# 2     First Fixation Duration       14_5_car-front-seat.png_face_N
# 3     First Fixation Duration       14_5_car-front-seat.png_face_N
# 4     First Fixation Duration       14_5_car-front-seat.png_face_N
# ...                       ...                                  ...
# 6722  First Fixation Duration  57_9_furniture.png_Not on AOI_Stdev
# 6723  First Fixation Duration  57_9_furniture.png_Not on AOI_Stdev
# 6724  First Fixation Duration  57_9_furniture.png_Not on AOI_Stdev
# 6725  First Fixation Duration  57_9_furniture.png_Not on AOI_Stdev
# 6726  First Fixation Duration  57_9_furniture.png_Not on AOI_Stdev
#
#                  image         AOI measurement
# 0     5_car-front-seat        face           N
# 1     5_car-front-seat        face           N
# 2     5_car-front-seat        face           N
# 3     5_car-front-seat        face           N
# 4     5_car-front-seat        face           N
# ...                ...         ...         ...
# 6722       9_furniture  Not on AOI       Stdev
# 6723       9_furniture  Not on AOI       Stdev
# 6724       9_furniture  Not on AOI       Stdev
# 6725       9_furniture  Not on AOI       Stdev
# 6726       9_furniture  Not on AOI       Stdev
#
# [6727 rows x 8 columns]

# %%
analysis_columns = ['ID number','image', 'AOI', 'metric', 'measurement','value','Sequence'] 
first_fixation_dur_seq_df = first_fixation_dur_df.join(subjects_df.set_index("ID number"), on="ID number", rsuffix='_subject')[analysis_columns]
first_fixation_dur_seq_df
# Out:
#            ID number             image         AOI                   metric  \
# 0               P001  5_car-front-seat        face  First Fixation Duration
# 1               P002  5_car-front-seat        face  First Fixation Duration
# 2               P003  5_car-front-seat        face  First Fixation Duration
# 3               P004  5_car-front-seat        face  First Fixation Duration
# 4               P005  5_car-front-seat        face  First Fixation Duration
# ...              ...               ...         ...                      ...
# 6722            P027       9_furniture  Not on AOI  First Fixation Duration
# 6723            P028       9_furniture  Not on AOI  First Fixation Duration
# 6724            P029       9_furniture  Not on AOI  First Fixation Duration
# 6725            P030       9_furniture  Not on AOI  First Fixation Duration
# 6726  All Recordings       9_furniture  Not on AOI  First Fixation Duration
#
#      measurement value Sequence
# 0              N     1        A
# 1              N     1        E
# 2              N     1        F
# 3              N     1        A
# 4              N     -        B
# ...          ...   ...      ...
# 6722       Stdev     -        F
# 6723       Stdev     -        A
# 6724       Stdev     -        B
# 6725       Stdev     -        C
# 6726       Stdev  0,11      NaN
#
# [6727 rows x 7 columns]

# %%
sequence_order_primer_type_df = sequence_order_primer_type_df[(sequence_order_primer_type_df['primer-type'] ==
                               'functional') | (sequence_order_primer_type_df['primer-type'] == 'emotional')][['Sequence name/ Order', 'primer-type', 'primed-image'
                                                                                                              ]]

# %%
aoi_data_with_primers_df = pd.merge(sequence_order_primer_type_df, first_fixation_dur_seq_df, left_on=[
         'Sequence name/ Order', 'primed-image'], right_on=['Sequence','image']).rename(columns={'value_y': 'value',
                                                                                                'value_x': 'primer-image-name'})

def clean_val(x):
    if isinstance(x, int):
        return x
    if x == '-':
        return None
    if ',' in x:
        return float(re.sub(',', '.', x))
    return float(x)
    

aoi_data_with_primers_df.value = aoi_data_with_primers_df.value.apply(clean_val)
aoi_data_with_primers_df[aoi_data_with_primers_df.image == '3_house'] .to_csv('test_results.csv') # test output
aoi_data_with_primers_df[aoi_data_with_primers_df['primer-type'] == 'functional']
# Out:
#      Sequence name/ Order primer-type primed-image ID number     image  \
# 0                       E  functional      3_house      P002   3_house
# 1                       E  functional      3_house      P008   3_house
# 2                       E  functional      3_house      P014   3_house
# 3                       E  functional      3_house      P020   3_house
# 4                       E  functional      3_house      P026   3_house
# ...                   ...         ...          ...       ...       ...
# 5791                    C  functional     7_coffee      P006  7_coffee
# 5792                    C  functional     7_coffee      P012  7_coffee
# 5793                    C  functional     7_coffee      P018  7_coffee
# 5794                    C  functional     7_coffee      P024  7_coffee
# 5795                    C  functional     7_coffee      P030  7_coffee
#
#              AOI                   metric measurement  value Sequence
# 0           face  First Fixation Duration           N    1.0        E
# 1           face  First Fixation Duration           N    1.0        E
# 2           face  First Fixation Duration           N    1.0        E
# 3           face  First Fixation Duration           N    1.0        E
# 4           face  First Fixation Duration           N    1.0        E
# ...          ...                      ...         ...    ...      ...
# 5791  Not on AOI  First Fixation Duration       Stdev    NaN        C
# 5792  Not on AOI  First Fixation Duration       Stdev    NaN        C
# 5793  Not on AOI  First Fixation Duration       Stdev    NaN        C
# 5794  Not on AOI  First Fixation Duration       Stdev    NaN        C
# 5795  Not on AOI  First Fixation Duration       Stdev    NaN        C
#
# [3052 rows x 10 columns]

# %%
emo_primers = aoi_data_with_primers_df[aoi_data_with_primers_df['primer-type'] == 'emotional']
funct_primers = aoi_data_with_primers_df[aoi_data_with_primers_df['primer-type'] == 'functional']

# %%
emo_primers.value
# Out:
# 105     1.00
# 106     1.00
# 107     1.00
# 108     1.00
# 109     1.00
#         ...
# 5875    0.16
# 5876     NaN
# 5877     NaN
# 5878     NaN
# 5879     NaN
# Name: value, Length: 2828, dtype: float64

# %%
funct_primers
# Out:
#      Sequence name/ Order primer-type primed-image ID number     image  \
# 0                       E  functional      3_house      P002   3_house
# 1                       E  functional      3_house      P008   3_house
# 2                       E  functional      3_house      P014   3_house
# 3                       E  functional      3_house      P020   3_house
# 4                       E  functional      3_house      P026   3_house
# ...                   ...         ...          ...       ...       ...
# 5791                    C  functional     7_coffee      P006  7_coffee
# 5792                    C  functional     7_coffee      P012  7_coffee
# 5793                    C  functional     7_coffee      P018  7_coffee
# 5794                    C  functional     7_coffee      P024  7_coffee
# 5795                    C  functional     7_coffee      P030  7_coffee
#
#              AOI                   metric measurement  value Sequence
# 0           face  First Fixation Duration           N    1.0        E
# 1           face  First Fixation Duration           N    1.0        E
# 2           face  First Fixation Duration           N    1.0        E
# 3           face  First Fixation Duration           N    1.0        E
# 4           face  First Fixation Duration           N    1.0        E
# ...          ...                      ...         ...    ...      ...
# 5791  Not on AOI  First Fixation Duration       Stdev    NaN        C
# 5792  Not on AOI  First Fixation Duration       Stdev    NaN        C
# 5793  Not on AOI  First Fixation Duration       Stdev    NaN        C
# 5794  Not on AOI  First Fixation Duration       Stdev    NaN        C
# 5795  Not on AOI  First Fixation Duration       Stdev    NaN        C
#
# [3052 rows x 10 columns]

# %%
gb_cols = ['primed-image', 'AOI']
measurement = 'Mean'
metric = 'First Fixation Duration'
func_primers_gb_agg = funct_primers[funct_primers['measurement'] == measurement].groupby(
    gb_cols).agg({'image': 'size', 'value': 'mean'}).rename(columns={'image': 'count'})
func_primers_gb_agg['primer'] = 'functional'
func_primers_gb_agg
# Out:
#                               count     value      primer
# primed-image     AOI
# 1_kitchen        Not on AOI      16  0.210000  functional
#                  Rectangle 2     16  0.218462  functional
#                  face            16  0.234286  functional
# 2_car-inside     Not on AOI      14  0.218182  functional
#                  Rectangle 2     14  0.280000  functional
#                  face            14  0.379286  functional
# 3_house          Not on AOI      16  0.150714  functional
#                  Rectangle 2     16  0.510000  functional
#                  face            16  0.459375  functional
# 4_floor-cleaner  Not on AOI      16  0.207692  functional
#                  Rectangle 2     16  0.227000  functional
#                  face            16  0.591333  functional
# 5_car-front-seat Not on AOI      16  0.144286  functional
#                  Rectangle 2     16  0.233333  functional
#                  face            16  0.261250  functional
# 6_bag            Not on AOI      14  0.175000  functional
#                  Rectangle 2     14  0.429167  functional
#                  face            14  0.345385  functional
# 7_coffee         Not on AOI      16  0.161538  functional
#                  Rectangle 2     16  0.220000  functional
#                  face            16  0.546000  functional
# 8_instrument     Not on AOI      16  0.185385  functional
#                  Rectangle 3     16  0.172143  functional
#                  face            16  0.227333  functional
# 9_furniture      Not on AOI      16  0.160667  functional
#                  Rectangle 2     16  0.263846  functional
#                  Rectangle 3     16  0.244286  functional
#                  face            16  0.326000  functional

# %%
emo_primers_gb_agg = emo_primers[emo_primers['measurement'] == measurement].groupby(
    gb_cols).mean()
emo_primers_gb_agg['primer'] = 'emotional'
aggregate_scores_both_primers = emo_primers_gb_agg.append(func_primers_gb_agg)
aggregate_scores_both_primers['measurement'] = measurement
aggregate_scores_both_primers['aggregate'] = 'mean'
aggregate_scores_both_primers['metric'] = metric
aggregate_scores_both_primers
# Out:
# /Users/sallyisa/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#                               count      primer     value measurement  \
# primed-image     AOI
# 1_kitchen        Not on AOI     NaN   emotional  0.193636        Mean
#                  Rectangle 2    NaN   emotional  0.310909        Mean
#                  face           NaN   emotional  0.330000        Mean
# 2_car-inside     Not on AOI     NaN   emotional  0.129167        Mean
#                  Rectangle 2    NaN   emotional  0.230000        Mean
#                  face           NaN   emotional  0.318667        Mean
# 3_house          Not on AOI     NaN   emotional  0.170000        Mean
#                  Rectangle 2    NaN   emotional  0.377273        Mean
#                  face           NaN   emotional  0.375714        Mean
# 4_floor-cleaner  Not on AOI     NaN   emotional  0.227857        Mean
#                  Rectangle 2    NaN   emotional  0.278750        Mean
#                  face           NaN   emotional  0.765000        Mean
# 5_car-front-seat Not on AOI     NaN   emotional  0.185833        Mean
#                  Rectangle 2    NaN   emotional  0.726250        Mean
#                  face           NaN   emotional  0.460833        Mean
# 6_bag            Not on AOI     NaN   emotional  0.188333        Mean
#                  Rectangle 2    NaN   emotional  0.248000        Mean
#                  face           NaN   emotional  0.273077        Mean
# 7_coffee         Not on AOI     NaN   emotional  0.210000        Mean
#                  Rectangle 2    NaN   emotional  0.510000        Mean
#                  face           NaN   emotional  0.596429        Mean
# 8_instrument     Not on AOI     NaN   emotional  0.176154        Mean
#                  Rectangle 3    NaN   emotional  0.231538        Mean
#                  face           NaN   emotional  0.291538        Mean
# 9_furniture      Not on AOI     NaN   emotional  0.249000        Mean
#                  Rectangle 2    NaN   emotional  0.310000        Mean
#                  Rectangle 3    NaN   emotional  0.230000        Mean
#                  face           NaN   emotional  0.285714        Mean
# 1_kitchen        Not on AOI    16.0  functional  0.210000        Mean
#                  Rectangle 2   16.0  functional  0.218462        Mean
#                  face          16.0  functional  0.234286        Mean
# 2_car-inside     Not on AOI    14.0  functional  0.218182        Mean
#                  Rectangle 2   14.0  functional  0.280000        Mean
#                  face          14.0  functional  0.379286        Mean
# 3_house          Not on AOI    16.0  functional  0.150714        Mean
#                  Rectangle 2   16.0  functional  0.510000        Mean
#                  face          16.0  functional  0.459375        Mean
# 4_floor-cleaner  Not on AOI    16.0  functional  0.207692        Mean
#                  Rectangle 2   16.0  functional  0.227000        Mean
#                  face          16.0  functional  0.591333        Mean
# 5_car-front-seat Not on AOI    16.0  functional  0.144286        Mean
#                  Rectangle 2   16.0  functional  0.233333        Mean
#                  face          16.0  functional  0.261250        Mean
# 6_bag            Not on AOI    14.0  functional  0.175000        Mean
#                  Rectangle 2   14.0  functional  0.429167        Mean
#                  face          14.0  functional  0.345385        Mean
# 7_coffee         Not on AOI    16.0  functional  0.161538        Mean
#                  Rectangle 2   16.0  functional  0.220000        Mean
#                  face          16.0  functional  0.546000        Mean
# 8_instrument     Not on AOI    16.0  functional  0.185385        Mean
#                  Rectangle 3   16.0  functional  0.172143        Mean
#                  face          16.0  functional  0.227333        Mean
# 9_furniture      Not on AOI    16.0  functional  0.160667        Mean
#                  Rectangle 2   16.0  functional  0.263846        Mean
#                  Rectangle 3   16.0  functional  0.244286        Mean
#                  face          16.0  functional  0.326000        Mean
#
#                              aggregate                   metric
# primed-image     AOI
# 1_kitchen        Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 2_car-inside     Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 3_house          Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 4_floor-cleaner  Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 5_car-front-seat Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 6_bag            Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 7_coffee         Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 8_instrument     Not on AOI       mean  First Fixation Duration
#                  Rectangle 3      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 9_furniture      Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  Rectangle 3      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 1_kitchen        Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 2_car-inside     Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 3_house          Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 4_floor-cleaner  Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 5_car-front-seat Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 6_bag            Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 7_coffee         Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 8_instrument     Not on AOI       mean  First Fixation Duration
#                  Rectangle 3      mean  First Fixation Duration
#                  face             mean  First Fixation Duration
# 9_furniture      Not on AOI       mean  First Fixation Duration
#                  Rectangle 2      mean  First Fixation Duration
#                  Rectangle 3      mean  First Fixation Duration
#                  face             mean  First Fixation Duration

# %%
emo_primers[emo_primers['measurement'] == 'Mean'].groupby('primed-image').count()
# Out:
#                   Sequence name/ Order  primer-type  ID number  image  AOI  \
# primed-image
# 1_kitchen                           42           42         42     42   42
# 2_car-inside                        48           48         48     48   48
# 3_house                             42           42         42     42   42
# 4_floor-cleaner                     42           42         42     42   42
# 5_car-front-seat                    42           42         42     42   42
# 6_bag                               48           48         48     48   48
# 7_coffee                            42           42         42     42   42
# 8_instrument                        42           42         42     42   42
# 9_furniture                         56           56         56     56   56
#
#                   metric  measurement  value  Sequence
# primed-image
# 1_kitchen             42           42     36        42
# 2_car-inside          48           48     42        48
# 3_house               42           42     35        42
# 4_floor-cleaner       42           42     36        42
# 5_car-front-seat      42           42     32        42
# 6_bag                 48           48     35        48
# 7_coffee              42           42     24        42
# 8_instrument          42           42     39        42
# 9_furniture           56           56     43        56

# %%
emo_primers[emo_primers['measurement'] == 'Mean'].groupby('primed-image').mean()
# Out:
#                      value
# primed-image
# 1_kitchen         0.282500
# 2_car-inside      0.232857
# 3_house           0.317429
# 4_floor-cleaner   0.448056
# 5_car-front-seat  0.424062
# 6_bag             0.236857
# 7_coffee          0.447917
# 8_instrument      0.233077
# 9_furniture       0.273023

# %%
sequence_order_primer_type_df
# Out:
#      Sequence name/ Order primer-type       primed-image
# 0                       A  functional  4_floor-cleaner-4
# 1                       B   emotional  4_floor-cleaner-4
# 2                       C   emotional     2_car-inside-3
# 3                       D  functional     2_car-inside-3
# 4                       E  functional  4_floor-cleaner-4
# ...                   ...         ...                ...
# 1699                    H  functional     2_car-inside-3
# 1700                    I  functional          1_kitchen
# 1701                    J   emotional          1_kitchen
# 1702                    K  functional  4_floor-cleaner-1
# 1703                    L   emotional  4_floor-cleaner-1
#
# [576 rows x 3 columns]

# %%
def analyze_measture(measure_name, measurement):
    tobii_measure_df = pd.read_csv(
        'summary-stats/{}.txt'.format(measure_name), delimiter='\t')
    tobii_measure_df = tobii_measure_df.melt(
        id_vars=tobii_measure_df.columns[0])
    tobii_measure_df = tobii_measure_df.rename(
        columns={"Unnamed: 0": "ID number"})
    tobii_measure_df['metric'] = measure_name
    tobii_measure_df['image_AOI_measure'] = tobii_measure_df[[
        'metric', 'variable']].apply(lambda x: re.sub(x[0]+'_', '', x[1]), axis=1)
    tobii_measure_df['image'] = tobii_measure_df['image_AOI_measure'].apply(
        get_image_name)
    tobii_measure_df['AOI'] = tobii_measure_df['image_AOI_measure'].apply(
        lambda x: x.split("_")[-2])
    tobii_measure_df['measurement'] = tobii_measure_df['image_AOI_measure'].apply(
        lambda x: x.split("_")[-1])
    # return tobii_measure_df
    analysis_columns = ['ID number', 'image', 'AOI',
                        'metric', 'measurement', 'value', 'Sequence']
    tobii_measure_seq_df = tobii_measure_df.join(subjects_df.set_index(
        "ID number"), on="ID number", rsuffix='_subject')[analysis_columns]
    tobii_measure_seq_df.to_csv('test_results.csv')
    # return tobii_measure_seq_df
    #return sequence_order_primer_type_df, tobii_measure_df
    aoi_data_with_primers_df = pd.merge(sequence_order_primer_type_df, tobii_measure_seq_df, left_on=[
        'Sequence name/ Order', 'primed-image'], right_on=['Sequence', 'image']).rename(columns={'value_y': 'value',
                                                                                                 'value_x': 'primer-image-name'})
    #return tobii_measure_seq_df, aoi_data_with_primers_df
    def clean_val(x):
        if isinstance(x, int):
            return x
        if x == '-':
            return None
        if ',' in x:
            return float(re.sub(',', '.', x))
        return float(x)

    aoi_data_with_primers_df.value = aoi_data_with_primers_df.value.apply(
        clean_val)
    #return aoi_data_with_primers_df
    emo_primers= aoi_data_with_primers_df[aoi_data_with_primers_df['primer-type'] == 'emotional']
    funct_primers= aoi_data_with_primers_df[aoi_data_with_primers_df['primer-type'] == 'functional']

    gb_cols= ['primed-image', 'AOI']
    func_primers_gb_agg= funct_primers[funct_primers['measurement'] == measurement].groupby(
        gb_cols).agg({'image': 'size', 'value': 'mean'}).rename(columns={'image': 'count'})
    func_primers_gb_agg['primer']= 'functional'
    func_primers_gb_agg

    emo_primers_gb_agg= emo_primers[emo_primers['measurement'] == measurement].groupby(
        gb_cols).mean()
    emo_primers_gb_agg['primer']= 'emotional'
    aggregate_scores_both_primers= emo_primers_gb_agg.append(
        func_primers_gb_agg)
    aggregate_scores_both_primers['measurement']= measurement
    aggregate_scores_both_primers['aggregate']= measurement.lower()
    aggregate_scores_both_primers['metric']= measure_name

    emo_primers[emo_primers['measurement'] ==
                'Mean'].groupby('primed-image').count()

    emo_primers[emo_primers['measurement'] ==
                'Mean'].groupby('primed-image').mean()
    return aggregate_scores_both_primers

primers = analyze_measture('Time to First Fixation (Across Media)', 'Mean')
primers
# Out:
#                               count      primer      value measurement  \
# primed-image     AOI
# 1_kitchen        Not on AOI     NaN   emotional   0.029091        Mean
#                  Rectangle 2    NaN   emotional  12.870909        Mean
#                  face           NaN   emotional   1.716429        Mean
# 2_car-inside     Not on AOI     NaN   emotional   0.076667        Mean
#                  Rectangle 2    NaN   emotional   0.623333        Mean
#                  face           NaN   emotional   0.764000        Mean
# 3_house          Not on AOI     NaN   emotional   0.235000        Mean
#                  Rectangle 2    NaN   emotional   1.319091        Mean
#                  face           NaN   emotional   0.346429        Mean
# 4_floor-cleaner  Not on AOI     NaN   emotional   0.055000        Mean
#                  Rectangle 2    NaN   emotional   1.826250        Mean
#                  face           NaN   emotional   0.355000        Mean
# 5_car-front-seat Not on AOI     NaN   emotional   0.190000        Mean
#                  Rectangle 2    NaN   emotional   1.587500        Mean
#                  face           NaN   emotional   0.335000        Mean
# 6_bag            Not on AOI     NaN   emotional   0.226667        Mean
#                  Rectangle 2    NaN   emotional   2.059000        Mean
#                  face           NaN   emotional   0.254615        Mean
# 7_coffee         Not on AOI     NaN   emotional   0.304444        Mean
#                  Rectangle 2    NaN   emotional   1.990000        Mean
#                  face           NaN   emotional   0.272857        Mean
# 8_instrument     Not on AOI     NaN   emotional   0.193077        Mean
#                  Rectangle 3    NaN   emotional   0.874615        Mean
#                  face           NaN   emotional   0.730769        Mean
# 9_furniture      Not on AOI     NaN   emotional   0.746000        Mean
#                  Rectangle 2    NaN   emotional   1.422727        Mean
#                  Rectangle 3    NaN   emotional   1.342500        Mean
#                  face           NaN   emotional   0.331429        Mean
# 1_kitchen        Not on AOI    16.0  functional   0.417143        Mean
#                  Rectangle 2   16.0  functional   1.155385        Mean
#                  face          16.0  functional   0.690000        Mean
# 2_car-inside     Not on AOI    14.0  functional   1.006364        Mean
#                  Rectangle 2   14.0  functional   0.899231        Mean
#                  face          14.0  functional   0.571429        Mean
# 3_house          Not on AOI    16.0  functional   0.140000        Mean
#                  Rectangle 2   16.0  functional   1.719231        Mean
#                  face          16.0  functional   0.464375        Mean
# 4_floor-cleaner  Not on AOI    16.0  functional   0.428462        Mean
#                  Rectangle 2   16.0  functional   0.735000        Mean
#                  face          16.0  functional   0.488000        Mean
# 5_car-front-seat Not on AOI    16.0  functional   0.147143        Mean
#                  Rectangle 2   16.0  functional   1.033333        Mean
#                  face          16.0  functional   0.360000        Mean
# 6_bag            Not on AOI    14.0  functional   0.171667        Mean
#                  Rectangle 2   14.0  functional   0.994167        Mean
#                  face          14.0  functional   0.296923        Mean
# 7_coffee         Not on AOI    16.0  functional   0.397692        Mean
#                  Rectangle 2   16.0  functional   0.100000        Mean
#                  face          16.0  functional   0.329333        Mean
# 8_instrument     Not on AOI    16.0  functional   0.300769        Mean
#                  Rectangle 3   16.0  functional   0.475714        Mean
#                  face          16.0  functional   0.624000        Mean
# 9_furniture      Not on AOI    16.0  functional   0.277333        Mean
#                  Rectangle 2   16.0  functional   2.059231        Mean
#                  Rectangle 3   16.0  functional   1.585714        Mean
#                  face          16.0  functional   0.566000        Mean
#
#                              aggregate                                 metric
# primed-image     AOI
# 1_kitchen        Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 2_car-inside     Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 3_house          Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 4_floor-cleaner  Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 5_car-front-seat Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 6_bag            Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 7_coffee         Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 8_instrument     Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 3      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 9_furniture      Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  Rectangle 3      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 1_kitchen        Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 2_car-inside     Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 3_house          Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 4_floor-cleaner  Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 5_car-front-seat Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 6_bag            Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 7_coffee         Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 8_instrument     Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 3      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)
# 9_furniture      Not on AOI       mean  Time to First Fixation (Across Media)
#                  Rectangle 2      mean  Time to First Fixation (Across Media)
#                  Rectangle 3      mean  Time to First Fixation (Across Media)
#                  face             mean  Time to First Fixation (Across Media)

# %%
seqs
# Out:
#      Sequence name/ Order primer-type       primed-image
# 0                       A  functional  4_floor-cleaner-4
# 1                       B   emotional  4_floor-cleaner-4
# 2                       C   emotional     2_car-inside-3
# 3                       D  functional     2_car-inside-3
# 4                       E  functional  4_floor-cleaner-4
# ...                   ...         ...                ...
# 1699                    H  functional     2_car-inside-3
# 1700                    I  functional          1_kitchen
# 1701                    J   emotional          1_kitchen
# 1702                    K  functional  4_floor-cleaner-1
# 1703                    L   emotional  4_floor-cleaner-1
#
# [576 rows x 3 columns]

# %%
sequence_order_primer_type_df
# Out:
#      Sequence name/ Order primer-type       primed-image
# 0                       A  functional  4_floor-cleaner-4
# 1                       B   emotional  4_floor-cleaner-4
# 2                       C   emotional     2_car-inside-3
# 3                       D  functional     2_car-inside-3
# 4                       E  functional  4_floor-cleaner-4
# ...                   ...         ...                ...
# 1699                    H  functional     2_car-inside-3
# 1700                    I  functional          1_kitchen
# 1701                    J   emotional          1_kitchen
# 1702                    K  functional  4_floor-cleaner-1
# 1703                    L   emotional  4_floor-cleaner-1
#
# [576 rows x 3 columns]

# %%
primers
# Out:
#            ID number                image         AOI  \
# 0               P001  14_5_car-front-seat        face
# 1               P002  14_5_car-front-seat        face
# 2               P003  14_5_car-front-seat        face
# 3               P004  14_5_car-front-seat        face
# 4               P005  14_5_car-front-seat        face
# ...              ...                  ...         ...
# 6722            P027       57_9_furniture  Not on AOI
# 6723            P028       57_9_furniture  Not on AOI
# 6724            P029       57_9_furniture  Not on AOI
# 6725            P030       57_9_furniture  Not on AOI
# 6726  All Recordings       57_9_furniture  Not on AOI
#
#                                      metric measurement value Sequence
# 0     Time to First Fixation (Across Media)           N     1        A
# 1     Time to First Fixation (Across Media)           N     1        E
# 2     Time to First Fixation (Across Media)           N     1        F
# 3     Time to First Fixation (Across Media)           N     1        A
# 4     Time to First Fixation (Across Media)           N     -        B
# ...                                     ...         ...   ...      ...
# 6722  Time to First Fixation (Across Media)       Stdev     -        F
# 6723  Time to First Fixation (Across Media)       Stdev     -        A
# 6724  Time to First Fixation (Across Media)       Stdev     -        B
# 6725  Time to First Fixation (Across Media)       Stdev     -        C
# 6726  Time to First Fixation (Across Media)       Stdev  1,06      NaN
#
# [6727 rows x 7 columns]
